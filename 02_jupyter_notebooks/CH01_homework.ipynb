# %% [markdown]
# # Problem 01 - Create random data and plot the linear multiplication results
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The data are obtained from the model
# $$
# x \mapsto y:=Ax + b
# $$
# with $x\in\mathbb R^{input\_dim}$ and $y\in\mathbb R^{output\_dim}$.

# %% [markdown]
# A: (output_dim, input_dim)
#
# y, b :   (output_dim, 1)
#
#
# Case 1:  when input_dim and out_dim are all equal to 1, A will be the slope for linear equation
#
# Case 2: when input_dim > 1 and out_dim =1, assume input_dim=768 (24 x 24) will be one image data into one vector. x (1, 768) will be one image,  A (1, 768) will be one row of weights
#
#
# We get a training set by randomly sampling and noisy observations
# \begin{align*}
# &x_i \sim U([-1, 1])\\
# &y_i = A x_i + b + \nu_i
# \end{align*}

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem 2 - Longest Substring Without Repeating Characters
#
# Given a string s, find the length of the longest
# substring without repeating character
#
#
# Example 1:
#
# Input: s = "abcabcbb"
#
# Output: 3
#
# Explanation: The answer is "abc", with the length of 3.
#
# Example 2:
#
# Input: s = "bbbbb"
#
# Output: 1
#
# Explanation: The answer is "b", with the length of 1.
#
# Example 3:
#
# Input: s = "pwwkew"
#
# Output: 3
#
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and n
#
# ot a substring.s.

# %%
# Hint:  use dict and two pointers, left, right =0 in the beginning

# %% [markdown]
# Problem 3 -Longest Palindrome (optional)
#
# Given a string s which consists of lowercase or uppercase letters, return the length of the longest palindrome that can be built with those letters.
#
# Letters are case sensitive, for example, "Aa" is not considered a palindrome her
#
# Example 1:
#
# Input: s = "abccccdd"
# Output: 7
# Explanation: One longest palindrome that can be built is "dccaccd", whose length is 7.
#
# Example 2:
#
# Input: s = "a"
# Output: 1
# Explanation: The longest palindrome that can be built is "a", whose length is 1.
#
# Constraints:
#
# 1 <= s.length <= 2000 s consists of lowercase and/or uppercase English letters only. e.

# %%
#Hint
